# %%
# %matplotlib widget

# %%
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np

fig = plt.figure()
ax = plt.axes(xlim=(-5, 5), ylim=(-1, 4))
line, = ax.plot([], [], lw=2)
circle, = ax.plot([], [], lw=2)
diagonal, = ax.plot([], [], lw=2)

agnesi_constant = 2

def init():
    line.set_data([], [])
    circle.set_data([], [])
    diagonal.set_data([], [])
    return line, circle, diagonal, horizontal, vertical

def witch_of_agnesi_fn(x):
    return (agnesi_constant ** 3) / (x**2 + agnesi_constant**2)

def diagonal_line_fn(x, offset):
    y = witch_of_agnesi_fn(x - offset)
    return ((y * (x - offset)) / np.sqrt((2*y) - (y**2)))

def animate(i):
    # plot woa
    x = np.arange(-10, 10, 0.1)
    y = witch_of_agnesi_fn(x)
    line.set_data(x, y)
    
    # plot circle
    radius = 1
    angle = np.linspace(0, 2 * np.pi, 150)
    c_x = radius * np.cos(angle)
    c_y = radius * (np.sin(angle) + 1)
    circle.set_data(c_x, c_y)

    # animation offset
    offset = 0.1 * i
    
    # diagonal line
    diag_y = diagonal_line_fn(5, offset)
    diagonal.set_data(5, diag_y)

    # horizontal and vertical lines
    #ax.axhline(2, xmin=-5, xmax=5, lw=1.5)
    #ax.axvline(0, ymin=-1, ymax=4, lw=1.5)

    return line, circle, diagonal, horizontal, vertical

#anim = animation.FuncAnimation(fig, animate, init_func=init, frames=200, interval=20, blit=True)
#anim.save('basic.gif', fps=30)

animate(0)
plt.grid()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
np.zeros((3, 3))
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.],
#        [0., 0., 0.]])
